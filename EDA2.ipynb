# %%
import pandas as pd

#Let's import some packages to create some charts in Python
  # matplotlib and seaborn for plotting
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv('application.csv')

# %%
# check top 5 recrds
df.head()
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0      100002       1         Cash loans           M            N
# 1      100003       0         Cash loans           F            N
# 2      100004       0    Revolving loans           M            Y
# 3      100006       0         Cash loans           F            N
# 4      100007       0         Cash loans           M            N
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0               Y             0          202500.0    406597.5      24700.5
# 1               N             0          270000.0   1293502.5      35698.5
# 2               Y             0           67500.0    135000.0       6750.0
# 3               Y             0          135000.0    312682.5      29686.5
# 4               Y             0          121500.0    513000.0      21865.5
#
#               ...              FLAG_DOCUMENT_18 FLAG_DOCUMENT_19  \
# ...

# %%
# check column information
df.columns.values
# Out:
# array(['SK_ID_CURR', 'TARGET', 'NAME_CONTRACT_TYPE', 'CODE_GENDER',
#        'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'CNT_CHILDREN',
#        'AMT_INCOME_TOTAL', 'AMT_CREDIT', 'AMT_ANNUITY', 'AMT_GOODS_PRICE',
#        'NAME_TYPE_SUITE', 'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE',
#        'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE',
#        'REGION_POPULATION_RELATIVE', 'DAYS_BIRTH', 'DAYS_EMPLOYED',
#        'DAYS_REGISTRATION', 'DAYS_ID_PUBLISH', 'OWN_CAR_AGE',
#        'FLAG_MOBIL', 'FLAG_EMP_PHONE', 'FLAG_WORK_PHONE',
#        'FLAG_CONT_MOBILE', 'FLAG_PHONE', 'FLAG_EMAIL', 'OCCUPATION_TYPE',
#        'CNT_FAM_MEMBERS', 'REGION_RATING_CLIENT',
#        'REGION_RATING_CLIENT_W_CITY', 'WEEKDAY_APPR_PROCESS_START',
#        'HOUR_APPR_PROCESS_START', 'REG_REGION_NOT_LIVE_REGION',
#        'REG_REGION_NOT_WORK_REGION', 'LIVE_REGION_NOT_WORK_REGION',
#        'REG_CITY_NOT_LIVE_CITY', 'REG_CITY_NOT_WORK_CITY',
#        'LIVE_CITY_NOT_WORK_CITY', 'ORGANIZATION_TYPE', 'EXT_SOURCE_1',
# ...

# %%
# check missing data
df.isnull().any()
# Out:
# SK_ID_CURR                    False
# TARGET                        False
# NAME_CONTRACT_TYPE            False
# CODE_GENDER                   False
# FLAG_OWN_CAR                  False
# FLAG_OWN_REALTY               False
# CNT_CHILDREN                  False
# AMT_INCOME_TOTAL              False
# AMT_CREDIT                    False
# AMT_ANNUITY                   False
# AMT_GOODS_PRICE                True
# NAME_TYPE_SUITE                True
# NAME_INCOME_TYPE              False
# NAME_EDUCATION_TYPE           False
# NAME_FAMILY_STATUS            False
# NAME_HOUSING_TYPE             False
# REGION_POPULATION_RELATIVE    False
# DAYS_BIRTH                    False
# DAYS_EMPLOYED                 False
# DAYS_REGISTRATION             False
# DAYS_ID_PUBLISH               False
# OWN_CAR_AGE                    True
# FLAG_MOBIL                    False
# FLAG_EMP_PHONE                False
# FLAG_WORK_PHONE               False
# FLAG_CONT_MOBILE              False
# ...

# %%
# check missing data
df.isnull().sum()
# Out:
# SK_ID_CURR                        0
# TARGET                            0
# NAME_CONTRACT_TYPE                0
# CODE_GENDER                       0
# FLAG_OWN_CAR                      0
# FLAG_OWN_REALTY                   0
# CNT_CHILDREN                      0
# AMT_INCOME_TOTAL                  0
# AMT_CREDIT                        0
# AMT_ANNUITY                       0
# AMT_GOODS_PRICE                  12
# NAME_TYPE_SUITE                  70
# NAME_INCOME_TYPE                  0
# NAME_EDUCATION_TYPE               0
# NAME_FAMILY_STATUS                0
# NAME_HOUSING_TYPE                 0
# REGION_POPULATION_RELATIVE        0
# DAYS_BIRTH                        0
# DAYS_EMPLOYED                     0
# DAYS_REGISTRATION                 0
# DAYS_ID_PUBLISH                   0
# OWN_CAR_AGE                   11430
# FLAG_MOBIL                        0
# FLAG_EMP_PHONE                    0
# FLAG_WORK_PHONE                   0
# FLAG_CONT_MOBILE                  0
# ...

# %%
# create a function to check missing data and generate report
def missing_data(data):
    total = data.isnull().sum().sort_values(ascending =False)
    percent = (data.isnull().sum()/data.isnull().count()*100).sort_values(ascending = False)
    return pd.concat([total,percent], axis=1,keys=['Total', 'Percent']) # When axis=1, a DataFrame is returned

# %%
missing_data(df).head(10)
# Out:
#                           Total    Percent
# COMMONAREA_AVG            12123  70.010395
# COMMONAREA_MODE           12123  70.010395
# COMMONAREA_MEDI           12123  70.010395
# NONLIVINGAPARTMENTS_MODE  12015  69.386694
# NONLIVINGAPARTMENTS_AVG   12015  69.386694
# NONLIVINGAPARTMENTS_MEDI  12015  69.386694
# FONDKAPREMONT_MODE        11873  68.566644
# LIVINGAPARTMENTS_AVG      11844  68.399168
# LIVINGAPARTMENTS_MODE     11844  68.399168
# LIVINGAPARTMENTS_MEDI     11844  68.399168

# %%
# basic statistical analysis
check_list=['AMT_INCOME_TOTAL', 'AMT_CREDIT', 'AMT_ANNUITY', 'AMT_GOODS_PRICE']
for i in check_list:
    print(df[i].describe())
# Out:
# count    1.731600e+04
# mean     1.747029e+05
# std      8.930165e+05
# min      2.565000e+04
# 25%      1.125000e+05
# 50%      1.440000e+05
# 75%      2.025000e+05
# max      1.170000e+08
# Name: AMT_INCOME_TOTAL, dtype: float64
# count    1.731600e+04
# mean     6.016119e+05
# std      4.040590e+05
# min      4.500000e+04
# 25%      2.700000e+05
# 50%      5.175000e+05
# 75%      8.134065e+05
# max      4.050000e+06
# Name: AMT_CREDIT, dtype: float64
# count     17316.000000
# mean      27140.813669
# std       14494.159196
# min        2052.000000
# 25%       16456.500000
# 50%       25065.000000
# 75%       34733.250000
# max      225000.000000
# Name: AMT_ANNUITY, dtype: float64
# count    1.730400e+04
# mean     5.408222e+05
# std      3.714269e+05
# min      4.500000e+04
# 25%      2.385000e+05
# 50%      4.500000e+05
# 75%      6.840000e+05
# max      4.050000e+06
# Name: AMT_GOODS_PRICE, dtype: float64

# %%
# Count number of records for each value:
df['TARGET'].value_counts()
# Out:
# 0    15962
# 1     1354
# Name: TARGET, dtype: int64

# %%
# Plot distribution
df['TARGET'].plot.hist(title = 'Load payed or not');
plt.xlabel('payed or not');
# 0 for the loan was repaid on time,1 indicating the client had payment difficulties

# %%
# Plot distribution
df['AMT_CREDIT'].plot.hist(title = 'Credit Distribution',color = 'green')
plt.xlabel('credit');

# %%
#check correlations
ext_data=df[['TARGET', 'EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3']]
ext_data_corrs = ext_data.corr()
ext_data_corrs
# Out:
#                 TARGET  EXT_SOURCE_1  EXT_SOURCE_2  EXT_SOURCE_3
# TARGET        1.000000     -0.154066     -0.147872     -0.187014
# EXT_SOURCE_1 -0.154066      1.000000      0.201357      0.179745
# EXT_SOURCE_2 -0.147872      0.201357      1.000000      0.101052
# EXT_SOURCE_3 -0.187014      0.179745      0.101052      1.000000

# %%
#  heatmap
sns.heatmap(ext_data_corrs, cmap = plt.cm.RdYlBu_r, vmin = -0.25, annot = True, vmax = 0.6)
plt.title('Correlation Heatmap');
# EXT_SOURCE featureshave negative correlations with the target, 
# indicating that as the value of the EXT_SOURCE increases, the client is more likely to repay the loan
